# %%
#Utilizo la libreria de Pandas
import pandas as pd

#Guarda los datos en un Data Frame llamdo dfCRE del archivo csv COLOMBIANOS_REGISTRADOS_EN_EL_EXTERIOR_20250403
dfCRE = pd.read_csv("COLOMBIANOS_REGISTRADOS_EN_EL_EXTERIOR_20250403.csv")
# Out:
# C:\Users\Edan\AppData\Local\Temp\ipykernel_51520\2109589165.py:5: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfCRE = pd.read_csv("COLOMBIANOS_REGISTRADOS_EN_EL_EXTERIOR_20250403.csv")

# %%
#Muestra la cantidad de filas y columnas del data set
dfCRE.shape
# Out:
# (1672255, 17)

# %%
#Metodo info() muestra la informacion de las columnas encabezado y el tipo de datos
dfCRE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672255 entries, 0 to 1672254
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   País                   1672255 non-null  object
#  1   Código ISO país        1672255 non-null  object
#  2   Ciudad de Residencia   1672255 non-null  object
#  3   Oficina de registro    1672255 non-null  object
#  4   Grupo edad             1672255 non-null  object
#  5   Edad (años)            1672255 non-null  int64
#  6   Área Conocimiento      1672255 non-null  object
#  7   Sub Area Conocimiento  1672255 non-null  object
#  8   Nivel Académico        1672255 non-null  object
#  9   Estado civil           1672255 non-null  object
#  10  Género                 1672255 non-null  object
#  11  Etnia de la persona    1672255 non-null  object
#  12  Estatura (CM)          1672255 non-null  object
#  13  Ciudad de Nacimiento   1672255 non-null  object
# ...

# %%
#Metodo value_counts los valores presentes en la columna país realiza el conteo de los valores con mas
#ocurrencias los muestra de orden decreciente en este caso muestra los 5 primeros con mas ocurrencias
#y los 5 ultimos con menos ocurrencias
dfCRE.País.value_counts()
# Out:
# País
# ESTADOS UNIDOS    492422
# ESPA�A            429353
# VENEZUELA         223027
# ECUADOR            89177
# CANADA             53926
#                    ...
# MAURITANIA             1
# BOTSUANA               1
# GUINEA-BISSAU          1
# BUTAN                  1
# ZAMBIA                 1
# Name: count, Length: 194, dtype: int64

# %%
#Muestra los encabezados, las 5 primeras filas y las 5 ultimas filas
dfCRE
# Out:
#                    País Código ISO país   Ciudad de Residencia  \
# 0                MEXICO             MEX   NUEVO LEON/MONTERREY
# 1               ALBANIA             ALB          TIRANE/FACESH
# 2              ALEMANIA             DEU          BERLIN/BERLIN
# 3              ALEMANIA             DEU          BERLIN/BERLIN
# 4               ECUADOR             ECU        PICHINCHA/QUITO
# ...                 ...             ...                    ...
# 1672250  ESTADOS UNIDOS             USA  CALIFORNIA/ORANGEVALE
# 1672251          ESPA�A             ESP          MADRID/MADRID
# 1672252  ESTADOS UNIDOS             USA   NEW JERSEY/ENGLEWOOD
# 1672253          ESPA�A             ESP         MURCIA/JUMILLA
# 1672254       VENEZUELA             VEN        ZULIA/MARACAIBO
#
#         Oficina de registro    Grupo edad  Edad (años)     Área Conocimiento  \
# 0                 C. MEXICO   ADOLESCENTE           16               NINGUNA
# ...

# %%
#Metodo columns muestra el encabezado de las columnas
dfCRE.columns
# Out:
# Index(['País', 'Código ISO país', 'Ciudad de Residencia',
#        'Oficina de registro', 'Grupo edad', 'Edad (años)', 'Área Conocimiento',
#        'Sub Area Conocimiento', 'Nivel Académico', 'Estado civil', 'Género',
#        'Etnia de la persona', 'Estatura (CM)', 'Ciudad de Nacimiento',
#        'Localización', 'Fecha de Registro', 'Cantidad de personas'],
#       dtype='object')

# %%
#Metodo head() muestra el encabezado de las columnas con el numero de las primeras 
#filas indicadas, inicia desde 0 con el numero indicado de filas 
dfCRE.head(20)
# Out:
#         País Código ISO país  Ciudad de Residencia Oficina de registro  \
# 0     MEXICO             MEX  NUEVO LEON/MONTERREY           C. MEXICO
# 1    ALBANIA             ALB         TIRANE/FACESH             C. ROMA
# 2   ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# 3   ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# 4    ECUADOR             ECU       PICHINCHA/QUITO            C. QUITO
# 5   ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# 6   ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# 7    CURA�AO             CUW    CURA�AO/WILLEMSTAD       C. WILLEMSTAD
# 8   ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# 9   ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# 10  ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# 11  ALEMANIA             DEU         BERLIN/BERLIN           C. BERLIN
# ...

# %%
#Metodo tail() muestra el encabezado de las columnas con las ultimas filas indicadas
#inicia desde la ultima fila con el numero indicado.
dfCRE.tail(10)
# Out:
#                         País Código ISO país   Ciudad de Residencia  \
# 1672245           COSTA RICA             CRI          HEREDIA/BARVA
# 1672246        NUEVA ZELANDA             NZL      AUCKLAND/AUCKLAND
# 1672247               ESPA�A             ESP      ANDALUCIA/GRANADA
# 1672248               ESPA�A             ESP         MADRID/COSLADA
# 1672249  FEDERACION DE RUSIA             RUS      BELGOROD/BELGOROD
# 1672250       ESTADOS UNIDOS             USA  CALIFORNIA/ORANGEVALE
# 1672251               ESPA�A             ESP          MADRID/MADRID
# 1672252       ESTADOS UNIDOS             USA   NEW JERSEY/ENGLEWOOD
# 1672253               ESPA�A             ESP         MURCIA/JUMILLA
# 1672254            VENEZUELA             VEN        ZULIA/MARACAIBO
#
#         Oficina de registro    Grupo edad  Edad (años)  \
# 1672245         C. SAN JOSE        ADULTO           31
# 1672246         C. AUCKLAND        ADULTO           38
# ...

# %%
#Metodo loc muestra las filas indicadas
dfCRE.loc[[100000, 200000, 800000]]
# Out:
#                   País Código ISO país Ciudad de Residencia  \
# 100000         ECUADOR             ECU      PICHINCHA/QUITO
# 200000  ESTADOS UNIDOS             USA    NEW JERSEY/NEWARK
# 800000          ESPA�A             ESP  CATALU�A/HOSPITALET
#
#        Oficina de registro    Grupo edad  Edad (años) Área Conocimiento  \
# 100000            C. QUITO        ADULTO           40           NINGUNA
# 200000           C. NEWARK        ADULTO           52           NINGUNA
# 800000        C. BARCELONA  ADULTO JOVEN           23           NINGUNA
#
#        Sub Area Conocimiento Nivel Académico Estado civil     Género  \
# 100000               NINGUNA       NO INDICA      SOLTERO  MASCULINO
# 200000               NINGUNA       NO INDICA       CASADO   FEMENINO
# 800000               NINGUNA    BACHILLERATO      SOLTERO  MASCULINO
#
#        Etnia de la persona Estatura (CM)          Ciudad de Nacimiento  \
# 100000             NINGUNA            -1   COLOMBIA/ANTIOQUIA/MEDELLIN
# ...

# %%
#Metodo unique muestra los valores unicos (sin duplicados) de la columna indicada
dfCRE["Nivel Académico"].unique()
# Out:
# array(['NO INDICA', 'BACHILLERATO', 'PRIMARIA', 'PREGRADO - PROFESIONAL',
#        'NINGUNO', 'POSTGRADO - MAESTRIA', 'POSTGRADO - DOCTORADO',
#        'PREGRADO - TECNOL�GICO', 'PREGRADO - T�CNICO PROFESIONAL',
#        'POSTGRADO - ESPECIALIZACI�N', '(NO REGISTRA)', 'SIN PROFESI�N',
#        'ESPECIALIZACI�N', 'TECNOL�GICA', 'UNIVERSITARIO',
#        'T�CNICA PROFESIONAL', 'MAESTRIA'], dtype=object)

# %%
#Metodo describe muestra una descripcion estadistica de la columna indicada
dfCRE["Nivel Académico"].describe()
# Out:
# count       1672255
# unique           17
# top       NO INDICA
# freq         757189
# Name: Nivel Académico, dtype: object

# %%
#Muestra los valores con la cantidad de ocurrencias en orden decreciente condicionado con la
#columna Genero FEMENINO y columna Nivel Académico
dfCRE[dfCRE['Género'] == 'FEMENINO'][['Género', "Nivel Académico"]].value_counts()
# Out:
# Género    Nivel Académico
# FEMENINO  NO INDICA                         414765
#           BACHILLERATO                      209928
#           PREGRADO - PROFESIONAL            111488
#           PRIMARIA                           55552
#           PREGRADO - T�CNICO PROFESIONAL     42596
#           POSTGRADO - MAESTRIA               23425
#           PREGRADO - TECNOL�GICO             19898
#           NINGUNO                            17276
#           POSTGRADO - ESPECIALIZACI�N        14856
#           POSTGRADO - DOCTORADO               4083
#           (NO REGISTRA)                        397
#           SIN PROFESI�N                        130
#           ESPECIALIZACI�N                        2
#           TECNOL�GICA                            1
# Name: count, dtype: int64

# %%
#Muestra los valores con la cantidad de ocurrencias en orden decreciente condicionado con la
#columna Genero FEMENINO y columna País
dfCRE[dfCRE['Género'] == 'FEMENINO'][['Género', "País"]].value_counts()
# Out:
# Género    País
# FEMENINO  ESTADOS UNIDOS                  269888
#           ESPA�A                          246522
#           VENEZUELA                       119954
#           ECUADOR                          44554
#           CANADA                           28690
#                                            ...
#           SAN VICENTE Y LAS GRANADINAS         1
#           TOGO                                 1
#           UZBEKISTAN                           1
#           YEMEN                                1
#           ZAMBIA                               1
# Name: count, Length: 184, dtype: int64

# %%
#Muestra los valores con la cantidad de ocurrencias en orden decreciente condicionado con la
#columna Nivel Académico PREGRADO - PROFESIONAL, ademas de las columnas Género, Nivel Académico y Ciudad de Nacimiento
dfCRE[dfCRE['Nivel Académico'] == 'PREGRADO - PROFESIONAL'][['Género', "Nivel Académico", "Ciudad de Nacimiento"]].value_counts()
# Out:
# Género       Nivel Académico         Ciudad de Nacimiento
# FEMENINO     PREGRADO - PROFESIONAL  COLOMBIA/CUNDINAMARCA/BOGOTA     22129
# MASCULINO    PREGRADO - PROFESIONAL  COLOMBIA/CUNDINAMARCA/BOGOTA     16602
# FEMENINO     PREGRADO - PROFESIONAL  COLOMBIA/VALLE DEL CAUCA/CALI     9886
#                                      (NO REGISTRA)                     9049
#                                      COLOMBIA/ANTIOQUIA/MEDELLIN       7979
#                                                                       ...
# DESCONOCIDO  PREGRADO - PROFESIONAL  COLOMBIA/BOYACA/SOCOTA               1
#                                      COLOMBIA/BOYACA/SANTANA              1
#                                      COLOMBIA/BOYACA/RONDON               1
#                                      COLOMBIA/BOYACA/DUITAMA              1
#                                      COLOMBIA/BOYACA/CUCAITA              1
# Name: count, Length: 5296, dtype: int64

# %%
#Metodo unique muestra los valores unicos (sin duplicados) de la columna indicada
dfCRE["Grupo edad"].unique()
# Out:
# array(['ADOLESCENTE', 'DESCONOCIDO', 'ADULTO', 'ADULTO JOVEN',
#        'ADULTO MAYOR', 'INFANTE', 'PRIMERA INFANCIA'], dtype=object)

# %%
#Metodo describe muestra una descripcion estadistica de la columna indicada
dfCRE["Fecha de Registro"].describe()
# Out:
# count     1672255
# unique        148
# top       2018-03
# freq        31492
# Name: Fecha de Registro, dtype: object

# %%
#Metodo unique muestra los valores unicos (sin duplicados) de la columna indicada
dfCRE["Fecha de Registro"].unique()
# Out:
# array(['2017-07', '2015-10', '2023-02', '2016-08', '2024-07', '2023-03',
#        '2021-10', '2022-06', '2022-04', '2022-05', '2021-12', '2021-08',
#        '2023-01', '2023-10', '2024-09', '2022-03', '2017-08', '2023-11',
#        '2024-04', '2016-05', '2022-09', '2023-04', '2025-03', '2024-06',
#        '2014-03', '2024-02', '2017-12', '2021-06', '2021-05', '2014-02',
#        '2014-05', '2018-05', '2023-12', '2024-03', '2022-08', '2013-04',
#        '2023-09', '2021-09', '2023-07', '2021-07', '2024-01', '2022-01',
#        '2019-11', '2014-08', '2013-11', '2022-10', '2022-07', '2023-05',
#        '2015-08', '2022-02', '2015-12', '2020-07', '2022-11', '2017-05',
#        '2024-05', '2024-08', '2018-09', '2021-11', '2013-10', '2020-08',
#        '2018-11', '2014-01', '2017-02', '2020-09', '2016-03', '2018-04',
#        '2017-03', '2013-12', '2023-06', '2020-10', '2017-11', '2015-09',
#        '2018-02', '2015-06', '2018-01', '2023-08', '2015-02', '2013-09',
# ...
